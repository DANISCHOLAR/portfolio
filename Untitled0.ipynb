# %% [markdown]
# <a href="https://colab.research.google.com/github/DANISCHOLAR/portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import sheets
sh = sheets.InteractiveSheet()
df = sh.as_df()
# Out:
# https://docs.google.com/spreadsheets/d/1wHGiQRcicF8UYzg_PXnyaVmyhLN4wox4yeyJe8v5O0U/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1wHGiQRcicF8UYzg_PXnyaVmyhLN4wox4yeyJe8v5O0U/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
